# %%
import MySQLdb as mdb
import sys
import pandas as pd
import plotly.plotly as py
from plotly.graph_objs import *
import matplotlib.pyplot as plt
import datetime
import numpy as np



try:
    con = mdb.connect('128.206.116.195', 'tg4_ro', '?3stEt7!3hUbRa-R', 'tw4_db');
    cursor = con.cursor()
    # Lists the tables in demo
    #sql = 'select * from tweet where job_id=4223 limit 1'
    #sql = 'select count(screen_name) from mention where screen_name = "POGGHI"'
    #sql = 'select count(screen_name) from mention where screen_name = "Jogja_Uncover"'
    #sql = 'select count(screen_name) from mention where screen_name = "infojogja"'
    #sql = 'select count(screen_name) from mention where screen_name = "iLikeKarenDaily"'
    #sql = 'select count(screen_name) from mention where screen_name = "CNSAV_OFFICIAL"'
    #sql = 'select count(screen_name) from mention where screen_name = "NinaByzantina"'
    #sql = 'select count(screen_name) from mention where screen_name = "StopRussia2014"'
    #sql = 'select count(screen_name) from mention where screen_name = "SooSuperior"'
    #sql = 'select count(screen_name) from mention where screen_name = "moscow_ghost"'
    #sql = 'select count(screen_name) from mention where screen_name = "VeraVanHorne"'
    #sql = 'select count(screen_name) from mention where screen_name = "Adam1Baum"'
    #sql = 'select count(screen_name) from mention where screen_name = "KingJames"'
    #sql = 'select count(screen_name) from mention where screen_name = "VELDFest"'
    #sql = 'select count(screen_name) from mention where screen_name = "watercolds"'
    #sql = 'select count(screen_name) from mention where screen_name = "KimKardashian"'
    #sql = 'select count(screen_name) from mention where screen_name = "the_boris"'
    #sql = 'select count(screen_name) from mention where screen_name = "barrokhfulsara"'
    #sql = 'select count(screen_name) from mention where screen_name = "VeraVanHorne"'
    #sql = 'select count(screen_name) from mention where screen_name = "Adam1Baum"'
    #sql = 'select count(screen_name) from mention where screen_name = "ladejugg84"'
    #sql = 'select count(screen_name) from mention where screen_name = "ArinanqY"'
    #sql = 'select count(screen_name) from mention where screen_name = "NinaByzantina"'
    #sql = 'select count(screen_name) from mention where screen_name = "StopRussia2014"'
    #sql = 'select count(screen_name) from mention where screen_name = "SooSuperior"'
    #sql = 'select count(screen_name) from mention where screen_name = "moscow_ghost"'
    #sql = 'select count(screen_name) from mention where screen_name = "VeraVanHorne"'
    #sql = 'select count(screen_name) from mention where screen_name = "Adam1Baum"'
    #sql = 'select count(screen_name) from mention where screen_name = "KingJames"'
    #sql = 'select count(screen_name) from mention where screen_name = "VELDFest"'
    #sql = 'select count(screen_name) from mention where screen_name = "watercolds"'
    #sql = 'select count(screen_name) from mention where screen_name = "KimKardashian"'
    #sql = 'select count(screen_name) from mention where screen_name = "the_boris"'
    #sql = 'select count(screen_name), timestamp from mention join history on mention.job_id where screen_name = "2010MisterChip" group by Month(timestamp)'
    #sql = 'select from_user_followers, screen_name from tweet join mention on mention.job_id = tweet.job_id where mention.job_id=4223 group by screen_name limit 100'
    # Execute the SQL query and get the response
    cursor.execute(sql)
    response = list(cursor.fetchall())
    
    for row in response:
        print(row[0])
   
        
               
    
except mdb.Error as e:
  
    print ("Error %d: %s" % (e.args[0],e.args[1]))
    sys.exit(1)
    
finally:    
        
    if con:    
        con.close()



import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model

x_train = np.array([224,152,40,181,2,316,581,2154,720,97,11,692,1503,621,566,385,72,410,199,452])
y_train = np.array([6455,3525,224,1019,6,11972,15906,40788,20330,2407,84,8635,27599,19049,14188,12711,5195,14766,
                   8010, 19210])
x_test = np.array([50,109,154,78,376, 222, 203, 186, 433, 301, 193, 333, 102, 181, 456, 284, 291, 167, 317, 99])
y_test = np.array([1411,3013,5005,2186,10174,7773,5991, 6291,18044,13864,4001,12310,6322,10931, 16692,5051, 
                  8612, 4754, 10,321])

x_train = x_train.reshape(-1,1)
x_test = x_test.reshape(-1,1)
print(len(x_test))
print(len(y_test))
print(len(x_train))
print(len(y_train))

regr = linear_model.LinearRegression()

regr.fit(x_train, y_train)

# The coefficients
print('Coefficients: \n', regr.coef_)
print("Residual sum of squares: %.2f"
      % np.mean((regr.predict(x_test) - y_test) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(x_test, y_test))


# Plot outputs
plt.scatter(x_test, y_test,  color='black')
plt.plot(x_test, regr.predict(x_test), color='blue',
         linewidth=3)

plt.xticks(())
plt.yticks(())
plt.savefig("linearRegPlot")
plt.show()
